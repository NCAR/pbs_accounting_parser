# %% [markdown]
# # Initial Data Exploration
# -------------------------------------

# %% [markdown]
# Messing around with a day's worth of PBS Accouting Data to see if we can figure anything useful out.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
path = '../csv_output/summary.csv'
df = pd.read_csv(path)

df.head()
# Out:
#     id      date r_type                   resource  \
# 0    8  20180212      Q                      queue
# 1    9  20180212      Q                      queue
# 2   10  20180212      Q                      queue
# 3   11  20180212      Q                      queue
# 4   12  20180212      Q                      queue
# 5   13  20180212      Q                      queue
# 6   14  20180212      Q                      queue
# 7   15  20180212      S                        NaN
# 8   15  20180212      S                      queue
# 9   15  20180212      S                    account
# 10  15  20180212      S        Resource_List.place
# 11  15  20180212      S                      group
# 12  15  20180212      S                      ctime
# 13  15  20180212      S    resource_assigned.ncpus
# 14  15  20180212      S        Resource_List.ncpus
# 15  15  20180212      S                      qtime
# 16  15  20180212      S     Resource_List.mpiprocs
# 17  15  20180212      S                 exec_vnode
# 18  15  20180212      S       Resource_List.select
# 19  15  20180212      S       Resource_List.select
# 20  15  20180212      S       Resource_List.select
# 21  15  20180212      S       Resource_List.select
# 22  15  20180212      S                    jobname
# 23  15  20180212      S                    project
# 24  15  20180212      S                      start
# 25  15  20180212      S     Resource_List.walltime
# 26  15  20180212      S                       user
# 27  15  20180212      S       Resource_List.nodect
# 28  15  20180212      S                      etime
# 29  15  20180212      S                  exec_host
# ..  ..       ...    ...                        ...
# 70  18  20180212      S     Resource_List.mpiprocs
# 71  18  20180212      S                 exec_vnode
# 72  18  20180212      S       Resource_List.select
# 73  18  20180212      S       Resource_List.select
# 74  18  20180212      S       Resource_List.select
# 75  18  20180212      S                    jobname
# 76  18  20180212      S                    project
# 77  18  20180212      S                      start
# 78  18  20180212      S     Resource_List.walltime
# 79  18  20180212      S                       user
# 80  18  20180212      S       Resource_List.nodect
# 81  18  20180212      S                      etime
# 82  18  20180212      S                  exec_host
# 83  18  20180212      S      resource_assigned.mem
# 84  20  20180212      E                      qtime
# 85  20  20180212      E                    session
# 86  20  20180212      E                    project
# 87  20  20180212      E                      group
# 88  20  20180212      E                Exit_status
# 89  20  20180212      E                      etime
# 90  20  20180212      E        resources_used.cput
# 91  20  20180212      E                      start
# 92  20  20180212      E  resources_used.cpupercent
# 93  20  20180212      E                 exec_vnode
# 94  20  20180212      E                  run_count
# 95  20  20180212      E        Resource_List.ncpus
# 96  20  20180212      E         resources_used.mem
# 97  20  20180212      E        Resource_List.place
# 98  20  20180212      E     Resource_List.mpiprocs
# 99  20  20180212      E     Resource_List.walltime
#
#                                                 value            key
# 0                                             economy            NaN
# 1                                             economy            NaN
# 2                                             economy            NaN
# 3                                             economy            NaN
# 4                                             economy            NaN
# 5                                             economy            NaN
# 6                                             economy            NaN
# 7                                                 NaN            NaN
# 8                                             economy            NaN
# 9                                          "SSSG0001"            NaN
# 10                                   scatter:exclhost            NaN
# 11                                               ncar            NaN
# 12                                         1518447436            NaN
# 13                                               4608            NaN
# 14                                               2304            NaN
# 15                                         1518447436            NaN
# 16                                                128            NaN
# 17  (r1i0n0:ncpus=36)+(r1i0n1:ncpus=36)+(r1i0n2:nc...            NaN
# 18                                                 64     mpiprocs:2
# 19                                                 64       ncpus:36
# 20                                                 64  ompthreads:18
# 21                                                 32       ncpus:14
# 22                                           zhpt64.2            NaN
# 23                               _pbs_project_default            NaN
# 24                                         1518447437            NaN
# 25                                           01:00:00            NaN
# 26                                              engel            NaN
# 27                                                 64            NaN
# 28                                         1518447436            NaN
# 29  r1i0n0/0*36+r1i0n1/0*36+r1i0n2/0*36+r1i0n3/0*3...            NaN
# ..                                                ...            ...
# 70                                                 96            NaN
# 71  (r1i0n0:ncpus=36)+(r1i0n1:ncpus=36)+(r1i0n2:nc...            NaN
# 72                                                 48     mpiprocs:2
# 73                                                 48       ncpus:36
# 74                                                 48  ompthreads:18
# 75                                           zhpt48.2            NaN
# 76                               _pbs_project_default            NaN
# 77                                         1518449574            NaN
# 78                                           01:00:00            NaN
# 79                                              engel            NaN
# 80                                                 48            NaN
# 81                                         1518449520            NaN
# 82  r1i0n0/0*36+r1i0n1/0*36+r1i0n2/0*36+r1i0n3/0*3...            NaN
# 83                                       3148374144kb            NaN
# 84                                         1518447436            NaN
# 85                                              19902            NaN
# 86                               _pbs_project_default            NaN
# 87                                               ncar            NaN
# 88                                                  0            NaN
# 89                                         1518449520            NaN
# 90                                          977:54:54            NaN
# 91                                         1518449574            NaN
# 92                                             173218            NaN
# 93  (r1i0n0:ncpus=36)+(r1i0n1:ncpus=36)+(r1i0n2:nc...            NaN
# 94                                                  1            NaN
# 95                                               1728            NaN
# 96                                        647553680kb            NaN
# 97                                   scatter:exclhost            NaN
# 98                                                 96            NaN
# 99                                           01:00:00            NaN
#
# [100 rows x 6 columns]

# %%
df = df.dropna(axis=0, subset=['resource'])

dfTime = df[df['resource'].str.contains('time')]
dfTime.head()
# Out:
#     id      date r_type                resource       value  key
# 12  15  20180212      S                   ctime  1518447436  NaN
# 15  15  20180212      S                   qtime  1518447436  NaN
# 25  15  20180212      S  Resource_List.walltime    01:00:00  NaN
# 28  15  20180212      S                   etime  1518447436  NaN
# 31  17  20180212      E                   qtime  1518447436  NaN

# %%
array = df.values
features = df.iloc[:, np.arange(1, len(df.columns), 1)]
labels = df.iloc[:, [0]]
feature_name = df.columns[1:len(df.columns)]

print(feature_name)

# feature extraction
# model = LogisticRegression()
# rfe = RFE(model, 3)
# fit = rfe.fit(features, labels)

# print("Num Features: %d") % fit.n_features_
# print("Selected Features: %s") % fit.support_
# print("Feature Ranking: %s") % fit.ranking_
# Out:
# Index([u'date', u'r_type', u'resource', u'value', u'key'], dtype='object')
