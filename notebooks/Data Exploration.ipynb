# %% [markdown]
# # Initial Data Exploration
# -------------------------------------

# %% [markdown]
# Messing around with a day's worth of PBS Accouting Data to see if we can figure anything useful out.

# %%
import pandas as pd
import numpy as np

# %%
path = '../csv_output/summary.csv'
df = pd.read_csv(path)

df.head(10)
# Out:
#    id      date r_type resource       value  key
# 0   8  20180212      Q    queue     economy  NaN
# 1   9  20180212      Q    queue     economy  NaN
# 2  10  20180212      Q    queue     economy  NaN
# 3  11  20180212      Q    queue     economy  NaN
# 4  12  20180212      Q    queue     economy  NaN
# 5  13  20180212      Q    queue     economy  NaN
# 6  14  20180212      Q    queue     economy  NaN
# 7  15  20180212      S      NaN         NaN  NaN
# 8  15  20180212      S    queue     economy  NaN
# 9  15  20180212      S  account  "SSSG0001"  NaN

# %% [markdown]
# We first have to know what we're working with so we can take a look at each column and see what it contains (not an exhaustive list)
#
# - **id**: The unique identification code for each job
# - **date**: The date the job was run
# - **r_type**: Record Type
#     - Q : Job entered a queue (not recorded for subjobs)
#     - S : Job execution has started
#     - E : Job or subjob ended
#     - A : Job was aborted
# - **resource**: Resources the job used/ information about the job
#     - user : Who submitted the job
#     - Resource_List.<resource> : List of resources requested by job (ncpus,mem...)
#     - Resource.used : Resources that were used in the job
#     - start : Time when job execution started (seconds since epoch)
#     - qtime : Time when job entered queue (seconds since epoch)
#     - Exit_status (keep in mind interactive jobs always return 0)
# - **value**: Value for each resource
# - **key**: Select statement values

# %% [markdown]
# Since how long a job takes to run is pretty important, I thought we could investigate this aspect first.

# %%
# Super basic, make a df out of every resource that has time in the name

df = df.dropna(axis=0, subset=['resource'])

dfTime = df[df['resource'].str.contains('time')]
dfTime.head(100)
# Out:
#      id      date r_type                 resource       value  key
# 12   15  20180212      S                    ctime  1518447436  NaN
# 15   15  20180212      S                    qtime  1518447436  NaN
# 25   15  20180212      S   Resource_List.walltime    01:00:00  NaN
# 28   15  20180212      S                    etime  1518447436  NaN
# 31   17  20180212      E                    qtime  1518447436  NaN
# 36   17  20180212      E                    etime  1518447436  NaN
# 46   17  20180212      E   Resource_List.walltime    01:00:00  NaN
# 53   17  20180212      E  resources_used.walltime    00:35:36  NaN
# 56   17  20180212      E                    ctime  1518447436  NaN
# 66   18  20180212      S                    ctime  1518447436  NaN
# 69   18  20180212      S                    qtime  1518447436  NaN
# 78   18  20180212      S   Resource_List.walltime    01:00:00  NaN
# 81   18  20180212      S                    etime  1518449520  NaN
# 84   20  20180212      E                    qtime  1518447436  NaN
# 89   20  20180212      E                    etime  1518449520  NaN
# 99   20  20180212      E   Resource_List.walltime    01:00:00  NaN
# 106  20  20180212      E  resources_used.walltime    00:36:06  NaN
# 109  20  20180212      E                    ctime  1518447436  NaN
# 119  21  20180212      S                    ctime  1518447436  NaN
# 122  21  20180212      S                    qtime  1518447436  NaN
# 131  21  20180212      S   Resource_List.walltime    01:00:00  NaN
# 134  21  20180212      S                    etime  1518451620  NaN
# 142  22  20180212      S                    ctime  1518447436  NaN
# 145  22  20180212      S                    qtime  1518447436  NaN
# 154  22  20180212      S   Resource_List.walltime    01:00:00  NaN
# 157  22  20180212      S                    etime  1518453720  NaN
# 160  23  20180212      E                    qtime  1518447436  NaN
# 165  23  20180212      E                    etime  1518451620  NaN
# 175  23  20180212      E   Resource_List.walltime    01:00:00  NaN
# 182  23  20180212      E  resources_used.walltime    00:35:30  NaN
# ..   ..       ...    ...                      ...         ...  ...
# 439  52  20180212      E  resources_used.walltime    00:34:58  NaN
# 442  52  20180212      E                    ctime  1518468620  NaN
# 452  53  20180212      S                    ctime  1518468620  NaN
# 455  53  20180212      S                    qtime  1518468620  NaN
# 464  53  20180212      S   Resource_List.walltime    01:00:00  NaN
# 467  53  20180212      S                    etime  1518470700  NaN
# 470  55  20180212      E                    qtime  1518468620  NaN
# 475  55  20180212      E                    etime  1518470700  NaN
# 485  55  20180212      E   Resource_List.walltime    01:00:00  NaN
# 492  55  20180212      E  resources_used.walltime    00:36:06  NaN
# 495  55  20180212      E                    ctime  1518468620  NaN
# 505  56  20180212      S                    ctime  1518468620  NaN
# 508  56  20180212      S                    qtime  1518468620  NaN
# 517  56  20180212      S   Resource_List.walltime    01:00:00  NaN
# 520  56  20180212      S                    etime  1518472800  NaN
# 528  57  20180212      S                    ctime  1518468620  NaN
# 531  57  20180212      S                    qtime  1518468620  NaN
# 540  57  20180212      S   Resource_List.walltime    01:00:00  NaN
# 543  57  20180212      S                    etime  1518474900  NaN
# 546  58  20180212      E                    qtime  1518468620  NaN
# 551  58  20180212      E                    etime  1518472800  NaN
# 561  58  20180212      E   Resource_List.walltime    01:00:00  NaN
# 568  58  20180212      E  resources_used.walltime    00:35:01  NaN
# 571  58  20180212      E                    ctime  1518468620  NaN
# 581  60  20180212      S                    ctime  1518468621  NaN
# 584  60  20180212      S                    qtime  1518468621  NaN
# 593  60  20180212      S   Resource_List.walltime    01:00:00  NaN
# 596  60  20180212      S                    etime  1518477000  NaN
# 599  61  20180212      E                    qtime  1518468620  NaN
# 604  61  20180212      E                    etime  1518474900  NaN
#
# [100 rows x 6 columns]

# %% [markdown]
# - ctime : time at which job was created
# - etime : time in which the job became eligible to run (in execution queue)
# - qtime : time job was queued
# - Resource_List.walltime : requested walltime
# - resource_used.walltime : time it actually took

# %% [markdown]
# From a quick glance at the data it seems a lot of jobs are submitted with a requested walltime of an hour, lets double check...

# %%
print ("Walltime: {}".format(dfTime.loc[(dfTime['resource'] == 'Resource_List.walltime') & (dfTime['r_type']== 'E'), 'value']))
# Out:
# Walltime: 46      01:00:00
# 99      01:00:00
# 175     01:00:00
# 228     01:00:00
# 281     01:00:00
# 311     01:00:00
# 365     01:00:00
# 432     01:00:00
# 485     01:00:00
# 561     01:00:00
# 614     01:00:00
# 644     01:00:00
# 697     01:00:00
# 773     01:01:01
# 823     01:01:01
# 873     01:01:01
# 923     01:01:01
# 973     01:01:01
# 1023    01:01:01
# 1073    01:01:01
# 1123    01:01:01
# 1173    01:01:01
# 1223    01:01:01
# 1273    01:01:01
# 1323    01:01:01
# 1373    01:01:01
# 1423    01:01:01
# 1473    01:01:01
# 1523    01:01:01
# 1573    01:01:01
# 1625    01:01:01
# 1673    01:01:01
# 1724    01:00:00
# Name: value, dtype: object

# %% [markdown]
# Just looked at the tutorial on the ncar webpage (see "Submitting jobs with PBS") and the example specifies a walltime of an hour. This might explain why a lot of users stick to that specific walltime. However, this means that this would not be a great variable to explore.
#
# In fact, we can go one of two ways here. We could either investigate ctime, etime and qtime to see how PBS is handling jobs and look for outliers or patterns there or we can go back to the main df to see if there are variables with a strong correlation with actual walltime.

# %%
e_jobs = df.loc[df['r_type']=='E']

e_jobs = e_jobs.drop(['date','r_type','key'], axis=1)

e_jobs.head(100)

# pivot = e_jobs.pivot(index='id', columns='resource')
# Out:
#      id                   resource  \
# 31   17                      qtime
# 32   17                    session
# 33   17                    project
# 34   17                      group
# 35   17                Exit_status
# 36   17                      etime
# 37   17        resources_used.cput
# 38   17                      start
# 39   17  resources_used.cpupercent
# 40   17                 exec_vnode
# 41   17                  run_count
# 42   17        Resource_List.ncpus
# 43   17         resources_used.mem
# 44   17        Resource_List.place
# 45   17     Resource_List.mpiprocs
# 46   17     Resource_List.walltime
# 47   17       Resource_List.select
# 48   17       Resource_List.select
# 49   17       Resource_List.select
# 50   17                       user
# 51   17                        end
# 52   17                    jobname
# 53   17    resources_used.walltime
# 54   17        resources_used.vmem
# 55   17                    account
# 56   17                      ctime
# 57   17       resources_used.ncpus
# 58   17                  exec_host
# 59   17                      queue
# 60   17       Resource_List.nodect
# ..   ..                        ...
# 170  23                  run_count
# 171  23        Resource_List.ncpus
# 172  23         resources_used.mem
# 173  23        Resource_List.place
# 174  23     Resource_List.mpiprocs
# 175  23     Resource_List.walltime
# 176  23       Resource_List.select
# 177  23       Resource_List.select
# 178  23       Resource_List.select
# 179  23                       user
# 180  23                        end
# 181  23                    jobname
# 182  23    resources_used.walltime
# 183  23        resources_used.vmem
# 184  23                    account
# 185  23                      ctime
# 186  23       resources_used.ncpus
# 187  23                  exec_host
# 188  23                      queue
# 189  23       Resource_List.nodect
# 213  26                      qtime
# 214  26                    session
# 215  26                    project
# 216  26                      group
# 217  26                Exit_status
# 218  26                      etime
# 219  26        resources_used.cput
# 220  26                      start
# 221  26  resources_used.cpupercent
# 222  26                 exec_vnode
#
#                                                  value
# 31                                          1518447436
# 32                                               15858
# 33                                _pbs_project_default
# 34                                                ncar
# 35                                                   0
# 36                                          1518447436
# 37                                          1280:19:30
# 38                                          1518447437
# 39                                              230718
# 40   (r1i0n0:ncpus=36)+(r1i0n1:ncpus=36)+(r1i0n2:nc...
# 41                                                   1
# 42                                                2304
# 43                                         863682604kb
# 44                                    scatter:exclhost
# 45                                                 128
# 46                                            01:00:00
# 47                                                  64
# 48                                                  64
# 49                                                  64
# 50                                               engel
# 51                                          1518449573
# 52                                            zhpt64.2
# 53                                            00:35:36
# 54                                         150450972kb
# 55                                          "SSSG0001"
# 56                                          1518447436
# 57                                                2304
# 58   r1i0n0/0*36+r1i0n1/0*36+r1i0n2/0*36+r1i0n3/0*3...
# 59                                             economy
# 60                                                  64
# ..                                                 ...
# 170                                                  1
# 171                                               1152
# 172                                        431530296kb
# 173                                   scatter:exclhost
# 174                                                 64
# 175                                           01:00:00
# 176                                                 32
# 177                                                 32
# 178                                                 32
# 179                                              engel
# 180                                         1518453870
# 181                                           zhpt32.2
# 182                                           00:35:30
# 183                                        150446228kb
# 184                                         "SSSG0001"
# 185                                         1518447436
# 186                                               1152
# 187  r1i0n0/0*36+r1i0n1/0*36+r1i0n2/0*36+r1i0n3/0*3...
# 188                                            economy
# 189                                                 32
# 213                                         1518447436
# 214                                              33313
# 215                               _pbs_project_default
# 216                                               ncar
# 217                                                  0
# 218                                         1518453720
# 219                                          321:03:35
# 220                                         1518453720
# 221                                              57659
# 222  (r1i1n16:ncpus=36)+(r1i1n17:ncpus=36)+(r1i2n0:...
#
# [100 rows x 3 columns]
